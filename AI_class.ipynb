# %% [markdown]
# <a href="https://colab.research.google.com/github/juliaeduarda-rg/IA-Classificacao-de-dinossauros/blob/main/AI_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IA do zero ao app

# %% [markdown]
# ## Contexto

# %% [markdown]
# Sem dados de treinamento suficientes, seus modelos de aprendizado profundo e aprendizado de máquina não podem aprender os padrões discriminativos subjacentes necessários para fazer classificações robustas.

# %% [markdown]
# O que levanta a questão:

# %% [markdown]
# Como você reúne imagens suficientes ao treinar modelos de aprendizado profundo?

# %% [markdown]
# Algoritmos de aprendizado profundo, especialmente Redes Neurais Convolucionais, podem ser feras famintas por dados.

# %% [markdown]
# E para piorar a situação, anotar manualmente um conjunto de dados de imagem pode ser um processo demorado, tedioso e até caro.

# %% [markdown]
# Então, existe uma maneira de aproveitar o poder das Imagens do Google para coletar imagens de treinamento rapidamente e, assim, reduzir o tempo necessário para criar seu conjunto de dados?

# %% [markdown]
# Pode apostar que existe.

# %% [markdown]
# No WS de hoje, demonstrarei como você pode usar o Imagens do Google para coletar dados de treinamento de maneira rápida (e fácil) para seus modelos de aprendizado profundo.

# %% [markdown]
# ## Preparação

# %% [markdown]
# Primeiro, configure seu colab para trabalhar com GPU. GPU, também chamada de 'palca de vídeo' são hardwares de processamento paralelo que funcionam muito melhor com DeepLearning

# %% [markdown]
# ![](https://media-exp1.licdn.com/dms/image/C5612AQESD6CvV-ja8Q/article-inline_image-shrink_1500_2232/0/1645765520416?e=1667433600&v=beta&t=x5Zjq-HD78L19b3yDFiSatGf0QsqEAjqWdI6-ogR724)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Scraping

# %% [markdown]
# Primeiro, instalamos e importamos um "Web Scraper", dependendo do contexto, também chamado de "crawler"
# Para saber mais funções dele no futuro, podes ler a documentação no link: https://icrawler.readthedocs.io/en/latest/builtin.html#search-engine-crawlers

# %%
# !pip install icrawler       > /dev/null     # dica: ao adicional             > /dev/null     a instalação ocorre de forma silenciosa, sem output.
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler
import warnings      # dica: você também pode silenciar avisos ignorando-os
warnings.filterwarnings("ignore")

# %% [markdown]
# Indique a palavra a ser pesquisada no google imagens, a quantidade e o local para salva-las e em seguida rode o Crawler

# %%
# Define a função que baixa as imagens
def take_images(keyword, max_num_img, server): # Informações
    # Esta biblioteca pode deixar de funcionar caso solicite mais de 1000 imagens
    # Roda o scraper
    local = f'./images/downloaded/{keyword}'
    if server == 'google':
        crawler = GoogleImageCrawler(storage={'root_dir': local})
    if server == 'bing':
        crawler = BingImageCrawler(storage={'root_dir': local})
    crawler.crawl(keyword=keyword, max_num=max_num_img)



# baixa diversas imagens de uma lista de classes
classes = ['tyrannosaurus rex', 'triceratops', 'stegosaurus']
for classe in classes:
    take_images(classe, max_num_img=100, server='google')
# Out:
# ERROR:downloader:Response status code 400, file https://www.thoughtco.com/thmb/P48oIUypkRZJNVx7mfkqe1NPeIk\u003d/5397x3238/filters:no_upscale():max_bytes(150000):strip_icc()/t-rex--artwork-460716257-5b9ae2b046e0fb0025f41a8c.jpg
# ERROR:downloader:Response status code 400, file https://th-thumbnailer.cdn-si-edu.com/3nk36-HdngLQbOzRySqrjnMKEno\u003d/1000x750/filters:no_upscale():focal(700x527:701x528)/https://tf-cmsv2-smithsonianmag-media.s3.amazonaws.com/filer_public/24/0c/240c2947-0038-47cb-ac80-75a50958ed08/meraxes-credit-carlos-papolio_web.jpg
# ERROR:downloader:Response status code 401, file https://i.guim.co.uk/img/media/30cfbaafc4d9fab780022d5733dd36b80b3acc3c/0_0_4800_3600/master/4800.jpg
# ERROR:downloader:Response status code 401, file https://i.guim.co.uk/img/media/5dab212de07d8009dd06560efeb1ac87b114e23d/0_640_4183_2510/master/4183.jpg
# ERROR:downloader:Response status code 400, file https://www.thoughtco.com/thmb/Ynj4VfJm_sEmM72qHEAs0rryqOo\u003d/5315x3646/filters:no_upscale():max_bytes(150000):strip_icc()/artwork-of-a-tyrannosaurus-rex-hunting-140891386-5b9ae2e146e0fb0025fa90e6.jpg
# ERROR:downloader:Response status code 400, file https://th-thumbnailer.cdn-si-edu.com/TIag41t2Q46thufarmL73xdaZRM\u003d/1000x750/filters:no_upscale():focal(960x540:961x541)/https://tf-cmsv2-smithsonianmag-media.s3.amazonaws.com/blogging/featured/Museum_display_of_a_T._rex_skeleton_eating_a_triceratops_skeleton..jpg
# ERROR:downloader:Response status code 401, file https://i.guim.co.uk/img/media/b0f29f8a13e50a18a00f615d83e02f75d4ce90ab/105_0_2895_1737/master/2895.jpg
# ERROR:downloader:Response status code 503, file https://www.science.org/do/10.1126/science.adb1808/abs/_03032022_sifter_trex.jpg
# ERROR:downloader:Response status code 503, file https://www.science.org/do/10.1126/science.aaf4192/abs/sn-trex.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Rjpalmer_tyrannosaurusrex_%28white_background%29.jpg
# ERROR:downloader:Response status code 400, file https://www.thoughtco.com/thmb/GzI_yevAkwnEeDv5ADSHs_G3XBM\u003d/5400x3785/filters:fill(auto,1)/triceratops-dinosaur--illustration-1155264985-37e99a7362b34c73a095aeaddad15ec6.jpg
# ERROR:downloader:Response status code 400, file https://th-thumbnailer.cdn-si-edu.com/leH0StL7Xw5dx4p8H9KxudzmDxs\u003d/fit-in/1600x0/filters:focal(761x420:762x421)/https://tf-cmsv2-smithsonianmag-media.s3.amazonaws.com/filer/52/6c/526c72be-21de-4a4c-9b4d-ac1851a0b707/92668.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Triceratops_by_Tom_Patker-01.jpg
# ERROR:downloader:Response status code 400, file https://www.thoughtco.com/thmb/NROICbVtnfzGPx5N-VLX18SS8V4\u003d/1800x1200/filters:no_upscale():max_bytes(150000):strip_icc()/Tyrannosaurus-Rex-5c7303aec9e77c00010d6c34.jpg
# ERROR:downloader:Response status code 400, file https://www.thoughtco.com/thmb/aCOTcsKdPXEs5wrq-twrPDFyCT4\u003d/5826x3277/smart/filters:no_upscale()/GettyImages-1149885212-9360a85a66374012b310538353c01147.jpg
# ERROR:downloader:Response status code 401, file https://i.guim.co.uk/img/media/aa52d4e19f078eb5508b0d7960006f788d96516c/0_50_1500_900/master/1500.jpg
# ERROR:downloader:Response status code 400, file https://www.thoughtco.com/thmb/wT4BPaMbh8ypX-EI6ojw8mZ0FhU\u003d/1200x688/filters:fill(auto,1)/ABlexovisaurus-56a253545f9b58b7d0c91353.jpg
# ERROR:downloader:Response status code 401, file https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/572e8900-9fdd-460b-9eec-2299b8ed6f80/deydgbp-11b1c476-b607-4434-b51e-c6776292247c.png
# ERROR:downloader:Response status code 400, file https://www.thoughtco.com/thmb/oaWcWEA2DIOl7IJHmTugLTJr8VQ\u003d/2000x1500/filters:fill(auto,1)/GettyImages-4958352951-5baaed8c4cedfd00253b4817.jpg
# ERROR:downloader:Response status code 401, file https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/8e0657fd-321b-49fe-941e-c71ef10a532b/db92dfl-45560c3d-9095-4377-bcd0-fdd004ebce06.png
# ERROR:downloader:Response status code 403, file https://www.researchgate.net/publication/226494530/figure/fig2/AS:670039564890123@1536761289508/Skeletal-reconstructions-of-two-Stegosaurus-species-at-same-scale-of-reduction-from-the.png
# ERROR:downloader:Response status code 400, file https://th-thumbnailer.cdn-si-edu.com/58V447DSJD0pPaWEFcp6FQRpbU4\u003d/fit-in/1600x0/https://tf-cmsv2-smithsonianmag-media.s3.amazonaws.com/filer/9a/3b/9a3bac72-cfad-426f-a29c-c274ab2a4dcc/42-43361965.jpg

# %% [markdown]
# Pronto! Agora temos as imagens salvas ali ao lado esquerdo no explorer. Caso você queira baixar novas imagens? Descomente a celula abaixo. Ela deleta todas as imagens baixadas.

# %%
from shutil import rmtree
#rmtree('/content/images')   #deleta tudo no diretório caso você queira recomeçar

# %% [markdown]
# ### Separação dos dados de Treino e Validação

# %%
from random import Random
import shutil
import os

keys = []

os.path.sep = '/'
# !cd "/content/"
for root, dirs, files in os.walk("./images/downloaded/"):
    for filename in files:
        keys.append(f"{root}/{filename}")

# Randomizar os inputs. (Vamos eliminar possibilidade de viés por ordem)
seed = 2022
randomizer = Random(seed)
randomizer.shuffle(keys)

input_files = []

for key in keys:
    input_files.append(key)

# Separa 20% dos dados para validação
test_split_size = 0.10
split_idx = int(len(input_files) * test_split_size)

train_input_files = input_files[:-split_idx]
val_input_files = input_files[-split_idx:]

# Criar diretórios para os dados de treino e validação
for file_train in train_input_files:
    train_path = f"./images/train/{file_train.split('/')[-2]}"
    os.makedirs(train_path, exist_ok=True)
    shutil.copy(file_train, f"{train_path}/{file_train.split('/')[-1]}")

for file_valid in val_input_files:
    valid_path = f"./images/valid/{file_valid.split('/')[-2]}"
    os.makedirs(valid_path, exist_ok=True)
    shutil.copy(file_valid, f"{valid_path}/{file_valid.split('/')[-1]}")

print(f'Train input files: {len(train_input_files)}')
print(f'Val input files: {len(val_input_files)}')
# Out:
# Train input files: 217
# Val input files: 24

# %% [markdown]
# ## Deeplearning Model

# %%
# !pip install fastai > /dev/null

# %%
from fastai.vision.all import *
from fastai.vision.augment import *
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ### Carregamento das imagens

# %%
path = Path("./images")

# Carrega as imagens e suas labels e ainda dividindo um grupo de teste com 20%
dataset = ImageDataLoaders.from_folder(path, item_tfms=RandomResizedCrop(128, min_scale=0.35), splitter=RandomSplitter(valid_pct=0.2, seed=42))

# visualisa o dataset
dataset.show_batch()

# %% [markdown]
# ### Escolhendo o modelo

# %% [markdown]
# ### Criando Entrada e saída

# %% [markdown]
# ### Treinando a IA

# %%
learn = vision_learner(dataset, resnet34, metrics=error_rate)         # testar usar eficientnetv2    e cnn_learner
learn.fine_tune(6)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.079305</td>
#       <td>3.035460</td>
#       <td>0.541667</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.512908</td>
#       <td>1.684098</td>
#       <td>0.500000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.266933</td>
#       <td>0.560035</td>
#       <td>0.375000</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.069423</td>
#       <td>0.329623</td>
#       <td>0.208333</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.917436</td>
#       <td>0.277037</td>
#       <td>0.208333</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.805884</td>
#       <td>0.265081</td>
#       <td>0.083333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.701466</td>
#       <td>0.298435</td>
#       <td>0.125000</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### aqui dá pra usar fast.ai ou tf

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Faça uma  predição

# %%
# Veja a curva de Loss 
learn.recorder.plot_loss()

# %%
learn.show_results(max_n=20)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ### Matriz de confusão

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ### outros

# %%
#Teste em uma imagem inteira

def predict(img):
    img=PILImage.create(img)
    labels = learn.dls.vocab
    pred, pred_idx, probs = learn.predict(img)
    predict_ = {labels[i]: float(probs[i]) for i in range(len(labels))}
    res = {key : round(predict_[key], 4) for key in predict_}   # aqui é só para arredondar
    return print(f'Probabilidade: {res}')

file_test = keys[0]    
predict(file_test)
Image.open(file_test)




def predict(img):
    img=PILImage.create(img)
    pred, pred_idx, probs = learn.predict(img)
    return {classes[i]: float(probs[i]) for i in range(len(classes))}
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Probabilidade: {'stegosaurus': 0.9056, 'triceratops': 0.0601, 'tyrannosaurus rex': 0.0343}

# %%
labels = learn.dls.vocab

def predict(img):
    img=PILImage.create(img)
    pred, pred_idx, probs = learn.predict(img)
    return {labels[i]: float(probs[i]) for i in range(len(labels))}

predict(file_test)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'stegosaurus': 0.9056380391120911,
#  'triceratops': 0.060085877776145935,
#  'tyrannosaurus rex': 0.03427611663937569}

# %% [markdown]
# ## Deploy

# %%
# Exportar o modelo
learn.export()

# %% [markdown]
# ### Gradio

# %%
# !pip install -q gradio
# Out:
#      |████████████████████████████████| 6.1 MB 27.6 MB/s
#      |████████████████████████████████| 55 kB 4.3 MB/s
#      |████████████████████████████████| 84 kB 3.9 MB/s
#      |████████████████████████████████| 57 kB 6.1 MB/s
#      |████████████████████████████████| 2.3 MB 60.9 MB/s
#      |████████████████████████████████| 112 kB 48.1 MB/s
#      |████████████████████████████████| 54 kB 3.5 MB/s
#      |████████████████████████████████| 84 kB 4.5 MB/s
#      |████████████████████████████████| 270 kB 70.6 MB/s
#      |████████████████████████████████| 212 kB 72.6 MB/s
#      |████████████████████████████████| 63 kB 2.3 MB/s
#      |████████████████████████████████| 80 kB 11.1 MB/s
#      |████████████████████████████████| 68 kB 8.8 MB/s
#      |████████████████████████████████| 43 kB 2.5 MB/s
#      |████████████████████████████████| 4.0 MB 42.0 MB/s
#      |████████████████████████████████| 856 kB 71.3 MB/s
#      |████████████████████████████████| 594 kB 63.5 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
import gradio
from gradio.components import Image, Label
gradio.Interface(fn=predict, inputs=Image(shape=(224,224)), outputs = Label(num_top_classes=2)).launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://21859.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://21859.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f079a887610>,
#  'http://127.0.0.1:7860/',
#  'https://21859.gradio.app')

# %% [markdown]
# # Extras

# %%
coloque sua aplicação na nuvem usando huggingFace + Gradio!!!!!

# %%
# se quiser retirar imagens do duckduckgo
'''
# !pip install -q jmd_imagescraper

from pathlib import Path
root = Path().cwd()/"images"

from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *

# a primeira string é o nome da pasta. a Segunta são as keywords
duckduckgo_search(root, "Cats", "cute kittens", max_results=10)
duckduckgo_search(root, "Dogs", "cute puppies", max_results=10)
duckduckgo_search(root, "Birds", "cute baby ducks and chickens", max_results=10)

'''
